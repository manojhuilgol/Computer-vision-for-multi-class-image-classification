# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import os
import zipfile

# %% [markdown]
# ### Importing all the 10 classes of bird samples

# %%
train_cane_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\cane')
train_cavallo_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\cavallo')
train_elefante_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\elefante')
train_farfalla_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\farfalla')
train_gallina_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\gallina')
train_gatto_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\gatto')
train_mucca_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\mucca')
train_pecora_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\pecora')
train_ragno_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\ragno')
train_scoiattolo_dir = os.path.join(r'G:\MS sem 2\Tensorflow\animals10\raw-img\scoiattolo')

# %%
train_cane = os.listdir(train_cane_dir)
train_cavallo = os.listdir(train_cavallo_dir)
print (train_cane[:10])
# Out:
# ['OIF-e2bexWrojgtQnAPPcUfOWQ.jpeg', 'OIP---A27bIBcUgX1qkbpZOPswHaFS.jpeg', 'OIP---cByAiEbIxIAleGo9AqOQAAAA.jpeg', 'OIP---ZIdwfUcJeVxnh47zppcQHaFj.jpeg', 'OIP---ZRsOF7zsMqhW30WeF8-AHaFj.jpeg', 'OIP---_cJbI6Ei26w5bW1urHewHaCf.jpeg', 'OIP--0C2kq6I68beB3DduLoxMgHaEf.jpeg', 'OIP--0CZnfLuBERVtzRm2QbB3gHaK4.jpeg', 'OIP--1QXriWyOTJg-9fEwbznmgHaI4.jpeg', 'OIP--2uTtzjaszBfEMCROuLN3wHaLH.jpeg']

# %% [markdown]
# ### Finding number of training samples for each kind of bird

# %%
directory = r'G:\MS sem 2\Tensorflow\animals10\raw-img'
for file_name in os.listdir(directory): 
    print ('Size of the training samples for the class', file_name, ':', len(os.listdir(directory + '\\' + file_name)))
# Out:
# Size of the training samples for the class cane : 4908
# Size of the training samples for the class cavallo : 2672
# Size of the training samples for the class elefante : 1483
# Size of the training samples for the class farfalla : 2464
# Size of the training samples for the class gallina : 3671
# Size of the training samples for the class gatto : 1941
# Size of the training samples for the class mucca : 2039
# Size of the training samples for the class pecora : 1942
# Size of the training samples for the class ragno : 5133
# Size of the training samples for the class scoiattolo : 2013

# %% [markdown]
# ### Displaying the sample images

# %%
from PIL import Image as PImage

def loadImages(path):
    # return array of images

    imagesList = os.listdir(path)
    loadedImages = []
    for image in imagesList:
        img = PImage.open(os.path.join(path,image))
        loadedImages.append(img)

    return loadedImages

path = r'G:\MS sem 2\Tensorflow\animals10\raw-img\cane'

# your images in an array
imgs = loadImages(path)

# %%
display (imgs[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x225 at 0x14E8326C3C8>
